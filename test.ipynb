# %%
from models.flux2_model_wrapper import Flux2ModelWrapper

model = Flux2ModelWrapper(device='mps')

# %%
# !pip uninstall -y diffusers
# !pip install git+https://github.com/huggingface/diffusers.git@main
# Out:
# Found existing installation: diffusers 0.36.0
# Uninstalling diffusers-0.36.0:
#   Successfully uninstalled diffusers-0.36.0
# ...
#   Cloning https://github.com/huggingface/diffusers.git (to revision main) to /private/var/folders/r_/1p4mfp_168q7t576jlf4wryc0000gn/T/pip-req-build-_drncc16
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /private/var/folders/r_/1p4mfp_168q7t576jlf4wryc0000gn/T/pip-req-build-_drncc16
#   Resolved https://github.com/huggingface/diffusers.git to commit 2843b3d37ad7c83b44cdcd098b9c064e1569457d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.37.0.dev0-py3-none-any.whl size=4941405 sha256=c9209800692367e4b6563ade2035ea740702947fbb764985cb0c1b3ca1a29d14
# ...
